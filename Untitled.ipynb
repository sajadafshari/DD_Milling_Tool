# %%
import mill.mat
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-35-019ad7084dab> in <module>
# ----> 1 import mill.mat
#
# ModuleNotFoundError: No module named 'mill.mat'

# %%
x = loadmat('mill.mat')

# %%
from scipy.io import loadmat

# %%
x = loadmat('mill.mat')

# %%
x

# %%
x.vb

# %%
x.VB

# %%
VB.x
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-36-65f79b273c63> in <module>
# ----> 1 VB.x
#
# NameError: name 'VB' is not defined

# %%
X
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-37-b5fec669aca1> in <module>
# ----> 1 X
#
# NameError: name 'X' is not defined

# %%
x
# Out:
# {'__header__': b'MATLAB 5.0 MAT-file, Platform: PCWIN, Created on: Tue Nov 27 15:59:45 2007',
#  '__version__': '1.0',
#  '__globals__': [],
#  'mill': array([[(array([[1]], dtype=uint8), array([[1]], dtype=uint8), array([[0]], dtype=uint8), array([[2]], dtype=uint8), array([[1.5]]), array([[0.5]]), array([[1]], dtype=uint8), array([[-0.01708984],
#         [ 0.26367188],
#         [ 0.20751953],
#         ...,
#         [-0.80810547],
#         [-0.73242188],
#         [-0.57617188]]), array([[0.625     ],
#         [0.81054688],
#         [0.78125   ],
#         ...,
#         [1.38183594],
#         [1.30371094],
#         [1.52832031]]), array([[0.078125  ],
#         [0.08544922],
#         [0.078125  ],
#         ...,
#         [0.27587891],
#         [0.52246094],
#         [0.37841797]]), array([[0.31494141],
#         [0.30151367],
#         [0.30395508],
#         ...,
#         [0.3125    ],
#         [0.31738281],
#         [0.3112793 ]]), array([[0.08728027],
# ...

# %%
VB
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-39-015e410ca245> in <module>
# ----> 1 VB
#
# NameError: name 'VB' is not defined

# %%
VB['x']
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-40-e2da4145b908> in <module>
# ----> 1 VB['x']
#
# NameError: name 'VB' is not defined

# %%
('VB', 'O')
# Out:
# ('VB', 'O')

# %%
A=('VB', 'O')

# %%
A
# Out:
# ('VB', 'O')

# %%
('VB')
# Out:
# 'VB'

# %%
VB
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-45-015e410ca245> in <module>
# ----> 1 VB
#
# NameError: name 'VB' is not defined

# %%
x['VB']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-46-5f3e162c2d92> in <module>
# ----> 1 x['VB']
#
# KeyError: 'VB'

# %%
X[VB]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-47-4efc62726314> in <module>
# ----> 1 X[VB]
#
# NameError: name 'X' is not defined

# %%
x[VB]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-48-7f86aceede3d> in <module>
# ----> 1 x[VB]
#
# NameError: name 'VB' is not defined

# %%
x2 = loadmat('VB.mill.mat')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# C:\ProgramData\Anaconda3\lib\site-packages\scipy\io\matlab\mio.py in _open_file(file_like, appendmat)
#      30     try:
# ---> 31         return open(file_like, 'rb'), True
#      32     except IOError:
#
# FileNotFoundError: [Errno 2] No such file or directory: 'VB.mill.mat'
#
# During handling of the above exception, another exception occurred:
#
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-49-def285efedc1> in <module>
# ----> 1 x2 = loadmat('VB.mill.mat')
#
# C:\ProgramData\Anaconda3\lib\site-packages\scipy\io\matlab\mio.py in loadmat(file_name, mdict, appendmat, **kwargs)
#     205     """
#     206     variable_names = kwargs.pop('variable_names', None)
# --> 207     MR, file_opened = mat_reader_factory(file_name, appendmat, **kwargs)
# ...

# %%
x2 = loadmat('mill.mat')

# %%
x3=loadmat('mill.mat.VB')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# C:\ProgramData\Anaconda3\lib\site-packages\scipy\io\matlab\mio.py in _open_file(file_like, appendmat)
#      30     try:
# ---> 31         return open(file_like, 'rb'), True
#      32     except IOError:
#
# FileNotFoundError: [Errno 2] No such file or directory: 'mill.mat.VB'
#
# During handling of the above exception, another exception occurred:
#
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-51-ea7d995d2a01> in <module>
# ----> 1 x3=loadmat('mill.mat.VB')
#
# C:\ProgramData\Anaconda3\lib\site-packages\scipy\io\matlab\mio.py in loadmat(file_name, mdict, appendmat, **kwargs)
#     205     """
#     206     variable_names = kwargs.pop('variable_names', None)
# --> 207     MR, file_opened = mat_reader_factory(file_name, appendmat, **kwargs)
# ...

# %%
x

# %%
import matlab.mat

# %%
Data = loadmat('mill.mat')

# %%
Data

# %%
plot(Data)

# %%
import matplotlib.pyplot as plt

# %%
matplot('Data')

# %%
plt.plot(Data)

# %%
time = [0, 1, 2, 3]
position = [0, 100, 200, 300]

plt.plot(time, position)
plt.xlabel('Time (hr)')
plt.ylabel('Position (km)')

# %%
position
# Out:
# [0, 100, 200, 300]

# %%
Data
# Out:
# {'__header__': b'MATLAB 5.0 MAT-file, Platform: PCWIN, Created on: Tue Nov 27 15:59:45 2007',
#  '__version__': '1.0',
#  '__globals__': [],
#  'mill': array([[(array([[1]], dtype=uint8), array([[1]], dtype=uint8), array([[0]], dtype=uint8), array([[2]], dtype=uint8), array([[1.5]]), array([[0.5]]), array([[1]], dtype=uint8), array([[-0.01708984],
#         [ 0.26367188],
#         [ 0.20751953],
#         ...,
#         [-0.80810547],
#         [-0.73242188],
#         [-0.57617188]]), array([[0.625     ],
#         [0.81054688],
#         [0.78125   ],
#         ...,
#         [1.38183594],
#         [1.30371094],
#         [1.52832031]]), array([[0.078125  ],
#         [0.08544922],
#         [0.078125  ],
#         ...,
#         [0.27587891],
#         [0.52246094],
#         [0.37841797]]), array([[0.31494141],
#         [0.30151367],
#         [0.30395508],
#         ...,
#         [0.3125    ],
#         [0.31738281],
#         [0.3112793 ]]), array([[0.08728027],
# ...
